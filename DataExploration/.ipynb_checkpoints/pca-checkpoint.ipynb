# %% [markdown]
# **Imports**

# %%
import json
from pprint import pprint
import pandas as pd
import re
import string

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from pathlib import Path

from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /home/tim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/tim/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# # Constructing the basic dataset

# %%
data_folder = Path('../data/twint')
tweets_file = data_folder / '2019_april_may_#uber_EN.txt'

# %%
f = open(tweets_file, 'r')
lines = [l for l in f]
f.close()

# %%
tweets = [json.loads(l) for l in lines]
print(tweets[0])
# Out:
# {'id': 1134217832886149120, 'conversation_id': '1134217832886149120', 'created_at': 1559253578000, 'date': '2019-05-30', 'time': '23:59:38', 'timezone': '+0200', 'user_id': 803710812649033728, 'username': 'rokk3rfuel', 'name': 'Rokk3r Fuel ExO', 'place': '', 'tweet': '"The question prospective investors have to ask themselves about #Uber is not how much the stock has dipped since the #IPO, but do they think @Uber will be successful 10 years from now," says Managing Director of Rokk3r Fuel @LPFocused @CNBCClosingBell https://cnb.cx/2YRrRFw\xa0', 'mentions': ['uber', 'cnbcclosingbell'], 'urls': ['https://cnb.cx/2YRrRFw'], 'photos': [], 'replies_count': 0, 'retweets_count': 0, 'likes_count': 11, 'hashtags': ['#uber', '#ipo'], 'cashtags': [], 'link': 'https://twitter.com/Rokk3rFuel/status/1134217832886149120', 'retweet': False, 'quote_url': '', 'video': 0, 'near': '', 'geo': '', 'source': '', 'user_rt_id': '', 'user_rt': '', 'retweet_id': '', 'reply_to': [{'user_id': '803710812649033728', 'username': 'Rokk3rFuel'}, {'user_id': '19103481', 'username': 'Uber'}, {'user_id': '21778391', 'username': 'CNBCClosingBell'}], 'retweet_date': '', 'translate': '', 'trans_src': '', 'trans_dest': ''}

# %%
print('Number of tweets:\t%s' % len(tweets))
# Out:
# Number of tweets:	38493

# %% [markdown]
# ## Top 20 Hashtags

# %%
hashtags = [h for t in tweets for h in t['hashtags']]

# %%
from collections import Counter
hashtags_count = pd.DataFrame.from_dict(Counter(hashtags), orient='index', columns=['count']).sort_values(by='count', ascending=False)[:20]
hashtags_count
# Out:
#                  count
# #uber            39109
# #lyft             8089
# #taxi             2499
# #ipo              2028
# #tfl              1503
# #uk               1492
# #rideshare        1380
# #crypto           1282
# #np               1248
# #edm              1240
# #ubereats         1207
# #uberipo           968
# #tradewar          696
# #xrpcommunity      674
# #xrpthestandard    673
# #london            638
# #free              619
# #ridesharing       616
# #beats             578
# #doordash          577

# %% [markdown]
# ## Tweet Time Distribution

# %%
dates_to_n_tweets = {}

for t in tweets:
    date = t['date'].split('-')[1] + '-' + t['date'].split('-')[2]
    try:
        dates_to_n_tweets[date] = dates_to_n_tweets[date] + 1
    except:
        dates_to_n_tweets[date] = 0

sorted_dates = sorted(dates_to_n_tweets.items())
plt.figure(1, figsize=(40, 10))
plt.bar([e[0] for e in sorted_dates], [e[1] for e in sorted_dates])
plt.title('Number Tweets per day (April and May 2019)')
plt.xlabel('Day')
plt.ylabel('Number of Tweets')
plt.show()

# %% [markdown]
# # Text preparation

# %%
stop_words = stopwords.words('english')
tokenizer = TweetTokenizer()
lemmatizer = WordNetLemmatizer()

# %%
def word_tokenize(tweet):
    return tokenizer.tokenize(tweet)

def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

def preprocess_tweet_text(tweet):
    
    tweet = tweet.lower()
    #Remove numbers
    tweet = re.sub(r"[0-9]", '', tweet, flags=re.MULTILINE)
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Tokenize
    tweet_tokens = word_tokenize(tweet)
    # Remove non-alpha words
    filtered_words = [w for w in tweet_tokens if w.isalpha()]
    # Remove stopwords
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    lemma_words = [lemmatizer.lemmatize(w, pos=get_wordnet_pos(w)) for w in filtered_words]
    
    # Filter out short lemmas
    lemma_words = [w for w in lemma_words if len(w) > 2]
    
    return lemma_words

# %%
unique_usernames = {t['username'] for t in tweets}
users_to_documents = {u:[] for u in unique_usernames}

for tw in tweets:
    u = tw['username']
    t = preprocess_tweet_text(tw['tweet'])
    users_to_documents[u] = users_to_documents[u] + t

print(list(users_to_documents.items())[200])
# Out:
# ('marxnsparks', ['youre', 'strike', 'today', 'highly', 'recommend', 'give', 'this', 'listen', 'also', 'tell', 'your', 'friendscoworkers', 'not', 'scab', 'cross', 'the', 'picket', 'line', 'uberlyftstrike', 'majorityfm', 'lyft', 'driver', 'meeting', 'the', 'hub', 'today', 'for', 'the', 'strike', 'all', 'uberlyftstrike', 'ubershutdown', 'lyftstrike', 'lyft', 'uber'])

# %% [markdown]
# ## See document length distribution

# %%
lengths = {u:len(doc) for (u, doc) in users_to_documents.items()}
min = np.min(list(lengths.values()))
max = np.max(list(lengths.values()))
bins = np.linspace(start=min, stop=max, num=500, endpoint=True)

labels = list(range(499))

lengths_df = pd.DataFrame({'Doc': list(lengths.keys()), 'Length': list(lengths.values())})

s = pd.cut(lengths_df['Length'], bins=bins).value_counts()

print(s.head())
# Out:
# (15.509, 18.411]    275
# (9.705, 12.607]     271
# (6.804, 9.705]      269
# (12.607, 15.509]    264
# (3.902, 6.804]      233
# Name: Length, dtype: int64

# %% [markdown]
# ## Filter out any users that now have less than 100 tokens

# %%
print(len(users_to_documents.values()))
users_to_documents = {u:doc for (u, doc) in users_to_documents.items() if len(doc) >= 100}
print(len(users_to_documents.values()))
# Out:
# 3082
# 63

# %% [markdown]
# ## Filter out any users with a very low token variety

# %%
def lexical_diversity_percentage(tokens):
    return len(set(tokens)) / len(tokens) * 100

# %% [markdown]
# ### Token variety histogram

# %%
lexical_diversities = {u:lexical_diversity_percentage(doc) for (u, doc) in users_to_documents.items()}
lexical_div_df = pd.DataFrame.from_dict(lexical_diversities, orient='index', columns=['diversity'])
lexical_div_df.groupby('diversity')
plt.figure(1, figsize=(30, 10))
plt.title('Lexical Diversity of Documents')
plt.xlabel('Lexical Diversity in Percent')
lexical_div_df['diversity'].plot(kind='hist')

# %%
print(len(users_to_documents))
users_to_documents = {u:doc for (u, doc) in users_to_documents.items() if lexical_diversity_percentage(doc) >= 40}
len(users_to_documents)
# Out:
# 63
# 54

# %%
users_to_documents_df = pd.DataFrame.from_dict(users_to_documents, orient='index')
users_to_documents_df
# Out:
#                             0                1                   2    \
# jannatu52428010          archie          windsor  billiondollarloser
# radical_qu33n              this              isn                just
# qatariaansiva       ubersupport          clearly             mention
# 10baggersonly              crsm            great             article
# theprospect                 the   uberlyftstrike                come
# jesslivmo                  more           gender             dynamic
# teamcoworker             driver             pour           ourselves
# limophila          philadelphia      uberdrivers             present
# sarahbellelin              uber              and                lyft
# depressionsnack             may            stand          solidarity
# kari_paul                  alex             have               drive
# smoran26                    hey             uber              listen
# juliana_f_reyes            talk           friend                last
# deandettloff          elizabeth           warren                 the
# johanspelaez     uberlyftstrike             they               treat
# morewhit         uberlyftstrike             this                 the
# pioneerboston              some              the           protester
# is_wordpress              check              out                 gig
# petemuntean                 the   uberlyftstrike              reagan
# jjrodv                    today          support                 the
# popresistance            during           occupy               there
# repdebhaaland             shame   trumpappointed               labor
# mikebcorry                  use        carsmartt                they
# maximillian_alv            talk             with          disability
# ssworks                    uber          similar             company
# anatosaurus             imagine          america               where
# driveuniteddc           despite        crackdown             airport
# gentlemanrascal             the   uberlyftstrike          protestors
# is_php                      you             look                 for
# carbonederigau              ill      interviewed                this
# fitzthereporter          thread              fun              little
# elite_taxibcn               por              qué                uber
# mondiablue                there            still              driver
# boston_cab                 have          trouble                find
# puppykhan                   one             hand               these
# tomleykis                   you            admit                that
# raflegend193     uberlyftstrike              all                want
# anissasonovia            subpar              now                that
# proftwolf                  ummm             look                like
# dsmoothe32       uberlyftstrike  ridesharestrike                scab
# sophia_reuss               show              his                 app
# themrotter                 also              for                 the
# _drivers_united             the           effect                 the
# 420_bitcoin            everyone              say                uber
# nola_knows_                 the  castletonsqmall               about
# paulleary               opinion              new              worker
# csaid                      uber             lyft          protestors
# jumpingdaisies            state        treasurer             fionama
# quicktake                   san       franciscos                uber
# curaffairs                  our           thread        demonstrates
# jillkoenig                 more             than              driver
# ryandeto                 update              two                more
# itfglobalunion           demand       collective          bargaining
# jasonkalmeida          strongly            think                goal
#
#                                    3                4               5    \
# jannatu52428010              archibald  wednesdaywisdom          meghan
# radical_qu33n                    about              the          worker
# qatariaansiva                  support              msg           didnt
# 10baggersonly                     just          release  uberlyftstrike
# theprospect                     amidst           highly      anticipate
# jesslivmo                         work              for          driver
# teamcoworker                      into              our            work
# limophila                        their           demand            uber
# sarahbellelin    driversstrikebreakers            still            pick
# depressionsnack                   with             uber            lyft
# kari_paul                         with             uber             for
# smoran26                          your           driver            rate
# juliana_f_reyes                  night            about            what
# deandettloff            uberlyftstrike             cory          booker
# johanspelaez                      like             crap            uber
# morewhit                          kind      selfimposed       ignorance
# pioneerboston                     call              for        creation
# is_wordpress                    fiverr           create       wordpress
# petemuntean                   national          airport            just
# jjrodv                  uberlyftstrike              and            push
# popresistance                     call              for   generalstrike
# repdebhaaland                    board             will           allow
# mikebcorry                       allow              you          choose
# maximillian_alv             healthcare         activist    flyingfannie
# ssworks                          dodge           social        security
# anatosaurus                billionaire             brag           about
# driveuniteddc                   police              our          action
# gentlemanrascal                serious             this          strike
# is_php                       ecommerce          website             for
# carbonederigau                    live             show          around
# fitzthereporter                   data         exercise             ask
# elite_taxibcn                   cabify          podrían           subir
# mondiablue                        work        galveston  uberlyftstrike
# boston_cab                        taxi              cab         because
# puppykhan                      company            claim            they
# tomleykis                  ridesharing              and           other
# raflegend193                      safe       experience             get
# anissasonovia                     both             have          public
# proftwolf                         uber             drop       valuation
# dsmoothe32                         and              ant           still
# sophia_reuss                       the             back             end
# themrotter                        love              god         someone
# _drivers_united         uberlyftstrike             keep     reverberate
# 420_bitcoin                       lose          billion            last
# nola_knows_                       head           friend           house
# paulleary                   protection            could         reshape
# csaid                        galvanize        attention             and
# jumpingdaisies                   stood        yesterday             for
# quicktake                 headquarters             this       protestor
# curaffairs                       there             many            many
# jillkoenig                        have             file     arbitration
# ryandeto                        driver          contact             one
# itfglobalunion               agreement              and           legal
# jasonkalmeida                      the   uberlyftstrike          should
#
#                             6               7               8    \
# jannatu52428010        kendrick        castillo  uberlyftstrike
# radical_qu33n            either            when         company
# qatariaansiva             start           solve         problem
# 10baggersonly              uber            lyft     ridesharing
# theprospect             initial          public        offering
# jesslivmo                  more            what          driver
# teamcoworker                one             the            most
# limophila              official             the      greenlight
# sarahbellelin             rider             san       francisco
# depressionsnack          driver            dont             use
# kari_paul                  year             and            half
# smoran26                   need        increase          driver
# juliana_f_reyes           labor             can           learn
# deandettloff                the  uberlyftstrike             joe
# johanspelaez             driver            feel            poor
# morewhit                   that             can            cost
# pioneerboston          socalled           guild            uber
# is_wordpress        woocommerce         website     woocommerce
# petemuntean                 end       organizer            tell
# jjrodv                  against      neoliberal    exploitation
# popresistance            mayday             now           there
# repdebhaaland           company             get            rich
# mikebcorry               female          driver          course
# maximillian_alv      workingpod            this            week
# ssworks                     and        medicare    contribution
# anatosaurus                 how            much            they
# driveuniteddc          national         airport            last
# gentlemanrascal          wouldn            last             for
# is_php                     your          online        business
# carbonederigau              pst  uberlyftstrike     exexcellent
# fitzthereporter           inrix          crunch             the
# elite_taxibcn               los         precios          españa
# mondiablue            passenger             don            ride
# boston_cab       uberlyftstrike           stand          behind
# puppykhan                  just        software             for
# tomleykis                driver            just           bunch
# raflegend193            through             our             day
# anissasonovia               all         honesty            both
# proftwolf                  from             but         protest
# dsmoothe32                  out            full           force
# sophia_reuss               that          driver             see
# themrotter              explain            with          number
# _drivers_united             let            keep             the
# 420_bitcoin                year            need           learn
# nola_knows_                 use       carsmartt         instead
# paulleary                   gig         economy            firm
# csaid                 political         support            even
# jumpingdaisies         uberlyft          driver            take
# quicktake                 shout            over     loudspeaker
# curaffairs            excellent          reason         support
# jillkoenig               demand         against            uber
# ryandeto                   isnt          strike             say
# itfglobalunion        framework          ensure            uber
# jasonkalmeida               tax        increase            fund
#
#                             9    ...   392     393   394    395     396   397  \
# jannatu52428010            tyra  ...  None    None  None   None    None  None
# radical_qu33n              hire  ...  None    None  None   None    None  None
# qatariaansiva              this  ...  None    None  None   None    None  None
# juliana_f_reyes  None  None     None                 None
# deandettloff     None  None     None                 None
# johanspelaez     None  None     None                 None
# morewhit         None  None     None                 None
# pioneerboston    None  None     None                 None
# is_wordpress     None  None     None                 None
# petemuntean      None  None     None                 None
# jjrodv           None  None     None                 None
# popresistance    None  None     None                 None
# repdebhaaland    None  None     None                 None
# mikebcorry       None  None     None                 None
# maximillian_alv  None  None     None                 None
# ssworks          None  None     None                 None
# anatosaurus      None  None     None                 None
# driveuniteddc    None  None     None                 None
# gentlemanrascal  None  None     None                 None
# is_php           None  None     None                 None
# carbonederigau   None  None     None                 None
# fitzthereporter  None  None     None                 None
# elite_taxibcn    None  None     None                 None
# mondiablue       None  None     None                 None
# boston_cab       None  None     None                 None
# puppykhan        None  None     None                 None
# tomleykis        None  None     None                 None
# raflegend193     None  None     None                 None
# anissasonovia    None  None     None                 None
# proftwolf        None  None     None                 None
# dsmoothe32       None  None     None                 None
# sophia_reuss     None  None     None                 None
# themrotter       None  None     None                 None
# _drivers_united  None  None     None                 None
# 420_bitcoin      None  None     None                 None
# nola_knows_      None  None     None                 None
# paulleary        None  None     None                 None
# csaid            None  None     None                 None
# jumpingdaisies   None  None     None                 None
# quicktake        None  None     None                 None
# curaffairs       None  None     None                 None
# jillkoenig       None  None     None                 None
# ryandeto         None  None     None                 None
# itfglobalunion   None  None     None                 None
# jasonkalmeida    None  None     None                 None
#
# [54 rows x 402 columns]

# %% [markdown]
# # Constructing the Term/Document Matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
docs = users_to_documents.values()

# %%
def do_nothing(tokens):
    return tokens

vectorizer = TfidfVectorizer(lowercase=False, tokenizer=do_nothing, min_df=0.3)

X = vectorizer.fit_transform(docs)

# %%
tf_idf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
tf_idf_df
# Out:
#        about       all       and       but       can   company    driver  \
# 0   0.000000  0.000000  0.312253  0.000000  0.000000  0.000000  0.000000
# 1   0.132146  0.000000  0.075927  0.000000  0.000000  0.145634  0.259050
# 2   0.091149  0.097955  0.104744  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.334903  0.000000  0.000000  0.000000  0.238048
# 4   0.000000  0.000000  0.279893  0.000000  0.000000  0.089476  0.212210
# 5   0.104077  0.037283  0.159466  0.036378  0.117706  0.152933  0.158686
# 6   0.228550  0.000000  0.196978  0.059914  0.000000  0.062969  0.336026
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.072449
# 8   0.000000  0.000000  0.173813  0.000000  0.000000  0.000000  0.098836
# 9   0.000000  0.000000  0.205212  0.000000  0.000000  0.000000  0.311176
# 10  0.000000  0.000000  0.171504  0.208664  0.000000  0.000000  0.260062
# 11  0.000000  0.000000  0.166551  0.000000  0.409785  0.159728  0.426180
# 12  0.249860  0.067129  0.107672  0.262003  0.141290  0.000000  0.244904
# 13  0.227974  0.081665  0.043663  0.079685  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0
# 38        0.674380  0.000000  0.000000  0.000000  0.147076  0.000000  0.000000
# 39        0.179898  0.000000  0.000000  0.000000  0.000000  0.000000  0.123704
# 40        0.292573  0.114853  0.000000  0.187965  0.000000  0.000000  0.000000
# 41        0.176813  0.231367  0.000000  0.094662  0.115684  0.403487  0.000000
# 42        0.517439  0.112848  0.000000  0.000000  0.000000  0.098399  0.118602
# 43        0.304780  0.000000  0.000000  0.000000  0.239290  0.312978  0.000000
# 44        0.327223  0.000000  0.179520  0.047779  0.058389  0.000000  0.000000
# 45        0.318673  0.125099  0.256417  0.000000  0.000000  0.000000  0.000000
# 46        0.566635  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 47        0.400429  0.000000  0.000000  0.000000  0.000000  0.228444  0.183565
# 48        0.321867  0.070196  0.000000  0.057440  0.000000  0.061208  0.000000
# 49        0.330047  0.259128  0.000000  0.106020  0.000000  0.000000  0.000000
# 50        0.277709  0.000000  0.000000  0.111510  0.136273  0.000000  0.000000
# 51        0.239552  0.117549  0.120471  0.192376  0.117549  0.102498  0.000000
# 52        0.373123  0.000000  0.093822  0.000000  0.000000  0.079825  0.096214
# 53        0.239958  0.235496  0.120675  0.000000  0.000000  0.000000  0.123752
#
# [54 rows x 36 columns]

# %% [markdown]
# ## Perform the PCA

# %%
pca = PCA(n_components=10)
X_reduced = pca.fit_transform(data_scaled)

# %% [markdown]
# ## Analyze the percentage of explained variance per principal component

# %%
pd.DataFrame(pca.explained_variance_ratio_)
# Out:
#           0
# 0  0.130658
# 1  0.116898
# 2  0.092245
# 3  0.067784
# 4  0.058354
# 5  0.056979
# 6  0.046417
# 7  0.042031
# 8  0.038552
# 9  0.037680

# %% [markdown]
# ## 2D Plot

# %%
y = range(0, len(X_reduced))
plt.figure(1, figsize=(10, 10))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap=plt.cm.Set2, edgecolor='k')
plt.title('2D Plot')
# Out:
# Text(0.5, 1.0, '2D Plot')

# %% [markdown]
# ## 3D Plot

# %%
fig = plt.figure(1, figsize=(10, 10))
ax = Axes3D(fig, elev=-150, azim=110)
y = range(0, len(X_reduced))
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k')
ax.set_title("PCA 3D Plot")
# Out:
# Text(0.5, 0.92, 'PCA 3D Plot')

# %% [markdown]
# ## See the documents/users with highest MSE

# %%
inverse_transform_data = pca.inverse_transform(X_reduced)
MSE_score = ((data_scaled-inverse_transform_data)**2).sum(axis=1)

# %%
MSE_max_scores = list(MSE_score.nlargest(10).index)

# %%
docs_with_highest_mse_df = users_to_documents_df.iloc[MSE_max_scores]
docs_with_highest_mse_df
# Out:
#                            0                1           2           3    \
# qatariaansiva      ubersupport          clearly     mention     support
# dsmoothe32      uberlyftstrike  ridesharestrike        scab         and
# jasonkalmeida         strongly            think        goal         the
# anissasonovia           subpar              now        that        both
# csaid                     uber             lyft  protestors   galvanize
# paulleary              opinion              new      worker  protection
# morewhit        uberlyftstrike             this         the        kind
# itfglobalunion          demand       collective  bargaining   agreement
# theprospect                the   uberlyftstrike        come      amidst
# petemuntean                the   uberlyftstrike      reagan    national
#
#                            4           5          6          7         8    \
# qatariaansiva              msg       didnt      start      solve   problem
# dsmoothe32                 ant       still        out       full     force
# jasonkalmeida   uberlyftstrike      should        tax   increase      fund
# anissasonovia             have      public        all    honesty      both
# csaid                attention         and  political    support      even
# paulleary                could     reshape        gig    economy      firm
# morewhit           selfimposed   ignorance       that        can      cost
# itfglobalunion             and       legal  framework     ensure      uber
# theprospect             highly  anticipate    initial     public  offering
# petemuntean            airport        just        end  organizer      tell
#
#                     9    ...   392   393   394   395   396   397   398   399  \
# qatariaansiva      this  ...  None  None  None  None  None  None  None  None
# dsmoothe32         many  ...  None  None  None  None  None  None  None  None
# jasonkalmeida      eitc  ...  None  None  None  None  None  None  None  None
# anissasonovia      lyft  ...  None  None  None  None  None  None  None  None
# csaid            though  ...  None  None  None  None  None  None  None  None
# paulleary       dynamex  ...  None  None  None  None  None  None  None  None
# morewhit            the  ...  None  None  None  None  None  None  None  None
# itfglobalunion   driver  ...  None  None  None  None  None  None  None  None
# theprospect        from  ...  None  None  None  None  None  None  None  None
# petemuntean      police  ...  None  None  None  None  None  None  None  None
#
#                  400   401
# qatariaansiva   None  None
# dsmoothe32      None  None
# jasonkalmeida   None  None
# anissasonovia   None  None
# csaid           None  None
# paulleary       None  None
# morewhit        None  None
# itfglobalunion  None  None
# theprospect     None  None
# petemuntean     None  None
#
# [10 rows x 402 columns]

# %% [markdown]
# ### See the length of the documents/users with highest MSE

# %%
usernames_with_highest_mse = list(docs_with_highest_mse_df.index)
lengths_of_docs_with_highest_mse_df = pd.DataFrame.from_dict({u:len(users_to_documents[u]) for u in usernames_with_highest_mse}, orient='index', columns=['count']).sort_values(by='count', ascending=False)
lengths_of_docs_with_highest_mse_df
# Out:
#                 count
# itfglobalunion    206
# qatariaansiva     168
# theprospect       132
# csaid             130
# jasonkalmeida     129
# paulleary         122
# morewhit          110
# petemuntean       107
# dsmoothe32        105
# anissasonovia     104

# %% [markdown]
# ## See the documents/users with the lowest MSE

# %%
MSE_low_scores = list(MSE_score.nsmallest(10).index)

# %%
docs_with_lowest_mse_df = users_to_documents_df.iloc[MSE_low_scores]
docs_with_lowest_mse_df
# Out:
#                           0            1                   2    \
# is_php                    you         look                 for
# is_wordpress            check          out                 gig
# _drivers_united           the       effect                 the
# elite_taxibcn             por          qué                uber
# quicktake                 san   franciscos                uber
# deandettloff        elizabeth       warren                 the
# carbonederigau            ill  interviewed                this
# kari_paul                alex         have               drive
# jannatu52428010        archie      windsor  billiondollarloser
# limophila        philadelphia  uberdrivers             present
#
#                             3                4            5            6    \
# is_php                ecommerce          website          for         your
# is_wordpress             fiverr           create    wordpress  woocommerce
# _drivers_united  uberlyftstrike             keep  reverberate          let
# elite_taxibcn            cabify          podrían        subir          los
# quicktake          headquarters             this    protestor        shout
# deandettloff     uberlyftstrike             cory       booker          the
# carbonederigau             live             show       around          pst
# kari_paul                  with             uber          for         year
# jannatu52428010       archibald  wednesdaywisdom       meghan     kendrick
# limophila                 their           demand         uber     official
#
#                             7               8           9    ...   392   393  \
# is_php                   online        business        then  ...  None  None
# is_wordpress            website     woocommerce       store  ...  None  None
# _drivers_united            keep             the    pressure  ...  None  None
# elite_taxibcn           precios          españa      salida  ...  None  None
# quicktake                  over     loudspeaker        that  ...  None  None
# deandettloff     uberlyftstrike             joe       biden  ...  None  None
# carbonederigau   uberlyftstrike     exexcellent  discussion  ...  None  None
# kari_paul                   and            half         say  ...  None  None
# jannatu52428010        castillo  uberlyftstrike        tyra  ...  None  None
# limophila                   the      greenlight         hub  ...  None  None
#
#                   394   395   396   397   398   399   400   401
# is_php           None  None  None  None  None  None  None  None
# is_wordpress     None  None  None  None  None  None  None  None
# _drivers_united  None  None  None  None  None  None  None  None
# elite_taxibcn    None  None  None  None  None  None  None  None
# quicktake        None  None  None  None  None  None  None  None
# deandettloff     None  None  None  None  None  None  None  None
# carbonederigau   None  None  None  None  None  None  None  None
# kari_paul        None  None  None  None  None  None  None  None
# jannatu52428010  None  None  None  None  None  None  None  None
# limophila        None  None  None  None  None  None  None  None
#
# [10 rows x 402 columns]

# %% [markdown]
# ### See the length of the documents/users with lowest MSE

# %%
usernames_with_lowest_mse = list(docs_with_lowest_mse_df.index)
lengths_of_docs_with_lowest_mse_df = pd.DataFrame.from_dict({u:len(users_to_documents[u]) for u in usernames_with_lowest_mse}, orient='index', columns=['count']).sort_values(by='count', ascending=False)
lengths_of_docs_with_lowest_mse_df
# Out:
#                  count
# carbonederigau     216
# quicktake          200
# kari_paul          155
# _drivers_united    136
# is_wordpress       125
# is_php             121
# jannatu52428010    116
# deandettloff       108
# elite_taxibcn      102
# limophila          100

# %%
# number of components
n_pcs= pca.components_.shape[0]

# get the index of the most important feature on EACH component
# LIST COMPREHENSION HERE
most_important_feature_indexes_per_pc = {}

initial_feature_names = data_scaled.columns

dfs = []

for pc in range(n_pcs):
    components_enumerated = list(enumerate(pca.components_[pc]))
    components_sorted = sorted(components_enumerated, key=lambda x:np.abs(x[1]), reverse=True)
    features_imps = {initial_feature_names[i]:imp for (i, imp) in components_sorted}
    features_imps_df = pd.DataFrame.from_dict(features_imps, orient='index', columns = ['importance'] )[:20]
    dfs.append(features_imps_df)
    
i = 1
for df in dfs:
    print('PCA %d' % i)
    print(df)
    print('')
    i += 1
# Out:
# PCA 1
#                 importance
# uber              0.635264
# the              -0.383477
# lyft              0.302895
# driver            0.292828
# your             -0.197321
# you              -0.196636
# today            -0.167233
# not              -0.151093
# pay               0.131129
# can              -0.121267
# just             -0.111345
# this             -0.106289
# for              -0.099341
# and               0.090308
# but              -0.089637
# strike           -0.085725
# uberlyftstrike    0.077009
# all              -0.076678
# wage             -0.074986
# out              -0.071071
#
# PCA 2
#                 importance
# your              0.509475
# the              -0.394487
# out               0.362800
# driver           -0.350216
# uberlyftstrike    0.255404
# that             -0.221947
# strike           -0.162667
# wage             -0.137562
# company          -0.126662
# they             -0.122587
# with             -0.121170
# like              0.115546
# their            -0.112492
# pay              -0.102955
# about            -0.091595
# not              -0.089947
# people           -0.088334
# work             -0.086662
# you               0.085204
# just             -0.079425
#
# PCA 3
#                 importance
# uberlyftstrike    0.607363
# the               0.322601
# you              -0.258609
# their            -0.253692
# your             -0.242999
# will             -0.228232
# company          -0.198620
# work             -0.150399
# today             0.142345
# and              -0.141388
# can              -0.139439
# make             -0.132627
# lyft             -0.123007
# for              -0.117937
# uber              0.109777
# just              0.105787
# from              0.105307
# wage             -0.100632
# pay              -0.096868
# out              -0.096413
#
# PCA 4
#          importance
# their      0.434216
# and       -0.380882
# driver    -0.364299
# not        0.253450
# they       0.241916
# company    0.216487
# strike    -0.211390
# lyft      -0.184329
# how        0.172219
# wage      -0.164853
# take      -0.164493
# make      -0.147304
# the       -0.137549
# for       -0.137213
# from      -0.135646
# you       -0.129388
# like       0.117380
# your      -0.113876
# uber       0.105790
# today     -0.095997
#
# PCA 5
#          importance
# they      -0.406026
# the        0.389411
# not       -0.307295
# today     -0.298748
# pay        0.290333
# company    0.275737
# their      0.271011
# can       -0.169470
# have       0.167303
# driver    -0.149315
# and        0.139985
# strike    -0.134191
# just      -0.122101
# like      -0.121713
# out        0.116821
# this      -0.112778
# from      -0.108675
# but        0.104658
# you       -0.097243
# with      -0.096503
#
# PCA 6
#         importance
# you       0.357314
# will     -0.322278
# driver   -0.307489
# for      -0.303983
# uber      0.298546
# can       0.278624
# make      0.276962
# take      0.231638
# and      -0.184298
# work      0.167598
# but      -0.154794
# they     -0.152558
# get      -0.152287
# lyft      0.140197
# out      -0.132793
# the       0.126561
# that     -0.119041
# today     0.115871
# not      -0.115637
# just     -0.103123
#
# PCA 7
#         importance
# people    0.348289
# will     -0.331978
# make      0.323846
# can      -0.304471
# the      -0.280833
# work      0.264998
# not      -0.258890
# and       0.203825
# driver   -0.191050
# lyft     -0.186677
# they      0.179004
# you      -0.178985
# strike    0.178022
# that      0.152855
# this     -0.152551
# your     -0.106816
# wage      0.101880
# from     -0.100494
# out       0.090179
# about     0.081779
#
# PCA 8
#         importance
# for       0.529892
# their    -0.333961
# with      0.286882
# have      0.251782
# uber      0.241743
# people    0.230948
# they     -0.229409
# from     -0.229267
# driver   -0.204984
# this      0.175382
# like     -0.156932
# just      0.139393
# will      0.125522
# strike   -0.120406
# how       0.112947
# your     -0.111850
# out      -0.093368
# can       0.089026
# today    -0.086427
# not       0.080187
#
# PCA 9
#                 importance
# will             -0.370133
# driver            0.316801
# today            -0.298456
# have              0.289974
# and              -0.264692
# from              0.246627
# the              -0.232652
# can               0.227844
# lyft             -0.215862
# not              -0.210021
# you               0.189843
# wage              0.178230
# for               0.176778
# all              -0.173742
# uberlyftstrike    0.163456
# company           0.163367
# uber             -0.136448
# make             -0.092173
# with              0.086175
# out              -0.082159
#
# PCA 10
#                 importance
# work              0.458854
# today            -0.319606
# lyft              0.318635
# will              0.279517
# uber             -0.239557
# your             -0.210572
# people            0.209906
# make             -0.200887
# have              0.190611
# but               0.174827
# driver           -0.171378
# uberlyftstrike    0.159091
# this             -0.158816
# they              0.154520
# from              0.149151
# their            -0.134056
# wage             -0.125768
# for              -0.122706
# company          -0.110979
# can               0.105477

# %%
from sklearn.cluster import KMeans
