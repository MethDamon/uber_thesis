# %% [markdown]
# **Imports**

# %%
import json
from pprint import pprint
import pandas as pd
import re
import string

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from pathlib import Path

from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /home/tim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/tim/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# # Constructing the basic dataset

# %%
data_folder = Path('../data/twint')
tweets_file = data_folder / 'data.txt'

# %%
f = open(tweets_file, 'r')
lines = [l for l in f]
f.close()

# %%
tweets = [json.loads(l) for l in lines]
print(tweets[0])
# Out:
# {'id': 1134217832886149120, 'conversation_id': '1134217832886149120', 'created_at': 1559253578000, 'date': '2019-05-30', 'time': '23:59:38', 'timezone': '+0200', 'user_id': 803710812649033728, 'username': 'fuelvc', 'name': 'Fuel Venture Capital', 'place': '', 'tweet': '"The question prospective investors have to ask themselves about #Uber is not how much the stock has dipped since the #IPO, but do they think @Uber will be successful 10 years from now," says Managing Director of Rokk3r Fuel @LPFocused @CNBCClosingBell  https://cnb.cx/2YRrRFw\xa0', 'language': 'en', 'mentions': ['uber', 'cnbcclosingbell'], 'urls': ['https://cnb.cx/2YRrRFw'], 'photos': [], 'replies_count': 0, 'retweets_count': 0, 'likes_count': 11, 'hashtags': ['#uber', '#ipo'], 'cashtags': [], 'link': 'https://twitter.com/FuelVC/status/1134217832886149120', 'retweet': False, 'quote_url': '', 'video': 0, 'near': '', 'geo': '', 'source': '', 'user_rt_id': '', 'user_rt': '', 'retweet_id': '', 'reply_to': [{'user_id': '803710812649033728', 'username': 'FuelVC'}, {'user_id': '19103481', 'username': 'Uber'}, {'user_id': '21778391', 'username': 'CNBCClosingBell'}], 'retweet_date': '', 'translate': '', 'trans_src': '', 'trans_dest': ''}

# %%
print('Number of tweets:\t%s' % len(tweets))
# Out:
# Number of tweets:	51571

# %% [markdown]
# ## Top 20 Hashtags

# %%
hashtags = [h for t in tweets for h in t['hashtags']]

# %%
from collections import Counter
hashtags_count = pd.DataFrame.from_dict(Counter(hashtags), orient='index', columns=['count']).sort_values(by='count', ascending=False)[:20]
hashtags_count
# Out:
#                  count
# #uber            38685
# #lyft            15161
# #uberlyftstrike   3738
# #uberipo          3347
# #taxi             2469
# #ipo              2454
# #rideshare        1582
# #uk               1556
# #tfl              1510
# #uberstrike       1429
# #crypto           1307
# #np               1249
# #edm              1241
# #ubereats         1240
# #ridesharing       766
# #free              740
# #tradewar          706
# #xrpcommunity      674
# #xrpthestandard    673
# #london            664

# %% [markdown]
# ## Tweet Time Distribution

# %%
dates_to_n_tweets = {}

for t in tweets:
    date = t['date'].split('-')[1] + '-' + t['date'].split('-')[2]
    try:
        dates_to_n_tweets[date] = dates_to_n_tweets[date] + 1
    except:
        dates_to_n_tweets[date] = 0

sorted_dates = sorted(dates_to_n_tweets.items())
plt.figure(1, figsize=(40, 10))
plt.bar([e[0] for e in sorted_dates], [e[1] for e in sorted_dates])
plt.title('Number Tweets per day (April and May 2019)')
plt.xlabel('Day')
plt.ylabel('Number of Tweets')
plt.show()

# %% [markdown]
# # Text preparation

# %%
stop_words = stopwords.words('english')
tokenizer = TweetTokenizer()
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# %%
def word_tokenize(tweet):
    return tokenizer.tokenize(tweet)

def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

def preprocess_tweet_text(tweet):
    
    tweet = tweet.lower()
    #Remove numbers
    tweet = re.sub(r"[0-9]", '', tweet, flags=re.MULTILINE)
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Tokenize
    tweet_tokens = word_tokenize(tweet)
    # Remove non-alpha words
    filtered_words = [w for w in tweet_tokens if w.isalpha()]
    # Remove stopwords
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    stemmed = [stemmer.stem(w) for w in filtered_words]
    
    # Filter out short lemmas
    stemmed = [w for w in lemmatized if len(w) > 2]
    
    return stemmed

# %%
unique_usernames = {t['username'] for t in tweets}
users_to_documents = {u:[] for u in unique_usernames}

for tw in tweets:
    u = tw['username']
    t = preprocess_tweet_text(tw['tweet'])
    users_to_documents[u] = users_to_documents[u] + t

print(list(users_to_documents.items())[200])
# Out:
# ('hamzeianalytics', ['uber', 'discloses', 'loss', 'file', 'disclosure', 'never', 'claim', 'stable', 'genius', 'getalife'])

# %% [markdown]
# ## See document length distribution

# %%
lengths = {u:len(doc) for (u, doc) in users_to_documents.items()}
min = np.min(list(lengths.values()))
max = np.max(list(lengths.values()))
bins = np.linspace(start=min, stop=max, num=500, endpoint=True)

labels = list(range(499))

lengths_df = pd.DataFrame({'Doc': list(lengths.keys()), 'Length': list(lengths.values())})

s = pd.cut(lengths_df['Length'], bins=bins).value_counts()

s.head()
# Out:
# (1.0, 36.447]         22257
# (36.447, 71.894]       1688
# (71.894, 107.341]       467
# (107.341, 142.788]      189
# (142.788, 178.234]      106
# Name: Length, dtype: int64

# %% [markdown]
# ## Filter out any users that now have less than 100 tokens

# %%
print(len(users_to_documents.values()))
users_to_documents = {u:doc for (u, doc) in users_to_documents.items() if len(doc) >= 150}
print(len(users_to_documents.values()))
# Out:
# 439
# 223

# %% [markdown]
# ## Filter out any users with a very low token variety

# %%
def lexical_diversity_percentage(tokens):
    return len(set(tokens)) / len(tokens) * 100

# %% [markdown]
# ### Token variety histogram

# %%
lexical_diversities = {u:lexical_diversity_percentage(doc) for (u, doc) in users_to_documents.items()}
lexical_div_df = pd.DataFrame.from_dict(lexical_diversities, orient='index', columns=['diversity'])
lexical_div_df.groupby('diversity')
plt.figure(1, figsize=(30, 10))
plt.title('Lexical Diversity of Documents')
plt.xlabel('Lexical Diversity in Percent')
lexical_div_df['diversity'].plot(kind='hist')

# %%
print(len(users_to_documents))
users_to_documents = {u:doc for (u, doc) in users_to_documents.items() if lexical_diversity_percentage(doc) >= 50}
len(users_to_documents)
# Out:
# 223
# 223

# %%
users_to_documents_df = pd.DataFrame.from_dict(users_to_documents, orient='index')
users_to_documents_df
# Out:
#                          0          1           2         3          4     \
# desmondyuen1    siliconvalley       love        uber  everyone       else
# _algocapital          britain    capital         key    market       uber
# dougwalker43        sadiqkhan     tfltph     thelcdc   theltda   guardian
# freightwaves          request     follow         faa  approval     google
# douglasviplimo           goit        get      simply      best  chauffeur
# ...                       ...        ...         ...       ...        ...
# realmikelarson          share       uber         ipo       per     report
# zoomrides_io             zoom        app  technology       inc      found
# rlrottman                uber      begin        make     rider   feedback
# dmvrideshare             lyft       wean      driver       get     leaner
# financialbuzz           tesla  implement       heavy   expense        cut
#
#                      5          6           7          8     \
# desmondyuen1    jeffbezos   alphabet    softbank    goldman
# _algocapital         home    million        user     driver
# dougwalker43         uber       make         pay     proper
# freightwaves        drone   virginia       drone       uber
# douglasviplimo        nyc  newjersey        area       know
# ...                   ...        ...         ...        ...
# realmikelarson       talk  valuation      plunge        ish
# zoomrides_io          san      diego  california        app
# rlrottman          rating   actually        mean  something
# dmvrideshare    attrition      occur   naturally   dedicate
# financialbuzz        tsla       uber        lyft   elonmusk
#
#                                 9     ...  1626  1627  1628  1629  1630  1631  \
# desmondyuen1    pictwittercomyetcmmc  ...  None  None  None  None  None  None
# _algocapital                presence  ...  None  None  None  None  None  None
# dougwalker43                    wage  ...  None  None  None  None  None  None
# freightwaves                sandiego  ...  None  None  None  None  None  None
# douglasviplimo                  area  ...  None  None  None  None  None  None
# ...                              ...  ...   ...   ...   ...   ...   ...   ...
# realmikelarson                   bln  ...  None  None  None  None  None  None
# zoomrides_io                    give  ...  None  None  None  None  None  None
# rlrottman                    foresee  ...  None  None  None  None  None  None
# dmvrideshare                  driver  ...  None  None  None  None  None  None
# financialbuzz                expense  ...  None  None  None  None  None  None
#
#                 1632  1633  1634  1635
# desmondyuen1    None  None  None  None
# _algocapital    None  None  None  None
# dougwalker43    None  None  None  None
# freightwaves    None  None  None  None
# douglasviplimo  None  None  None  None
# ...              ...   ...   ...   ...
# realmikelarson  None  None  None  None
# zoomrides_io    None  None  None  None
# rlrottman       None  None  None  None
# dmvrideshare    None  None  None  None
# financialbuzz   None  None  None  None
#
# [223 rows x 1636 columns]

# %% [markdown]
# # Constructing the Term/Document Matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
docs = users_to_documents.values()

# %%
def do_nothing(tokens):
    return tokens

vectorizer = TfidfVectorizer(lowercase=False, tokenizer=do_nothing, min_df=0.25, max_df=0.6)

X = vectorizer.fit_transform(docs)

# %%
tf_idf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
tf_idf_df
# Out:
#          also       app      bad       big   billion  business      call  \
# 0    0.000000  0.000000  0.00000  0.478355  0.215287  0.000000  0.000000
# 1    0.237271  0.099948  0.00000  0.000000  0.292801  0.099948  0.000000
# 2    0.000000  0.149765  0.00000  0.000000  0.146248  0.000000  0.000000
# 3    0.000000  0.000000  0.00000  0.000000  0.126005  0.000000  0.000000
# 4    0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...      ...       ...       ...       ...       ...
# 218  0.132264  0.000000  0.00000  0.000000  0.108813  0.222859  0.000000
# 219  0.000000  0.493627  0.00000  0.000000  0.120509  0.123407  0.073241
# 220  0.097470  0.000000  0.09747  0.000000  0.000000  0.000000  0.000000
# 221  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 222  0.000000  0.000000  0.00000  0.000000  0.245969  0.000000  0.000000
#
#           car      city      come  ...   uberipo     ubers       use  \
# 0    0.391257  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1    0.088688  0.116091  0.099350  ...  0.000000  0.000000  0.105666
# 2    0.000000  0.173955  0.148870  ...  0.000000  0.000000  0.000000
# 3    0.114499  0.000000  0.256528  ...  0.000000  0.000000  0.136418
# 4    0.000000  0.000000  0.169778  ...  0.000000  0.000000  0.000000
# ..        ...       ...       ...  ...       ...       ...       ...
# 218  0.000000  0.000000  0.110764  ...  0.000000  0.000000  0.117805
# 219  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 220  0.182164  0.000000  0.040813  ...  0.000000  0.045745  0.000000
# 221  0.000000  0.000000  0.000000  ...  0.639629  0.384018  0.072878
# 222  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
#          want       way      week      well      work     would      year
# 0    0.000000  0.000000  0.000000  0.000000  0.221797  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.476787
# 2    0.000000  0.340651  0.176476  0.000000  0.000000  0.000000  0.142887
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.194246  0.000000  0.170798  0.171831  0.180570  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 218  0.000000  0.000000  0.000000  0.222859  0.000000  0.117805  0.318936
# 219  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 220  0.175869  0.046695  0.048381  0.041058  0.041306  0.086814  0.039172
# 221  0.073819  0.000000  0.000000  0.068934  0.000000  0.000000  0.065768
# 222  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [223 rows x 68 columns]

# %% [markdown]
# ## Performing a PCA

# %%
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.normalize(tf_idf_df), columns=tf_idf_df.columns)
data_scaled
# Out:
#          also       app      bad       big   billion  business      call  \
# 0    0.000000  0.000000  0.00000  0.478355  0.215287  0.000000  0.000000
# 1    0.237271  0.099948  0.00000  0.000000  0.292801  0.099948  0.000000
# 2    0.000000  0.149765  0.00000  0.000000  0.146248  0.000000  0.000000
# 3    0.000000  0.000000  0.00000  0.000000  0.126005  0.000000  0.000000
# 4    0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...      ...       ...       ...       ...       ...
# 218  0.132264  0.000000  0.00000  0.000000  0.108813  0.222859  0.000000
# 219  0.000000  0.493627  0.00000  0.000000  0.120509  0.123407  0.073241
# 220  0.097470  0.000000  0.09747  0.000000  0.000000  0.000000  0.000000
# 221  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 222  0.000000  0.000000  0.00000  0.000000  0.245969  0.000000  0.000000
#
#           car      city      come  ...   uberipo     ubers       use  \
# 0    0.391257  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1    0.088688  0.116091  0.099350  ...  0.000000  0.000000  0.105666
# 2    0.000000  0.173955  0.148870  ...  0.000000  0.000000  0.000000
# 3    0.114499  0.000000  0.256528  ...  0.000000  0.000000  0.136418
# 4    0.000000  0.000000  0.169778  ...  0.000000  0.000000  0.000000
# ..        ...       ...       ...  ...       ...       ...       ...
# 218  0.000000  0.000000  0.110764  ...  0.000000  0.000000  0.117805
# 219  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 220  0.182164  0.000000  0.040813  ...  0.000000  0.045745  0.000000
# 221  0.000000  0.000000  0.000000  ...  0.639629  0.384018  0.072878
# 222  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
#          want       way      week      well      work     would      year
# 0    0.000000  0.000000  0.000000  0.000000  0.221797  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.476787
# 2    0.000000  0.340651  0.176476  0.000000  0.000000  0.000000  0.142887
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.194246  0.000000  0.170798  0.171831  0.180570  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 218  0.000000  0.000000  0.000000  0.222859  0.000000  0.117805  0.318936
# 219  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 220  0.175869  0.046695  0.048381  0.041058  0.041306  0.086814  0.039172
# 221  0.073819  0.000000  0.000000  0.068934  0.000000  0.000000  0.065768
# 222  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [223 rows x 68 columns]

# %% [markdown]
# ## Perform the PCA

# %%
pca = PCA()
X_reduced = pca.fit_transform(data_scaled)

# %%
len(X_reduced[:, 0])
# Out:
# 223

# %% [markdown]
# ## Analyze the percentage of explained variance per principal component

# %%
pd.DataFrame(pca.explained_variance_ratio_)
# Out:
#            0
# 0   0.113396
# 1   0.080978
# 2   0.047518
# 3   0.043407
# 4   0.038523
# ..       ...
# 63  0.002638
# 64  0.002504
# 65  0.002322
# 66  0.001830
# 67  0.001655
#
# [68 rows x 1 columns]

# %%
explained_variance = pca.explained_variance_ratio_.sum()
print("Explained variance of the PCA step: {}%".format(int(explained_variance * 100)))
print()
# Out:
# Explained variance of the PCA step: 100%

# %% [markdown]
# ## 2D Plot

# %%
y = range(0, len(X_reduced))
plt.figure(1, figsize=(10, 10))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap=plt.cm.Set2, edgecolor='k')
plt.title('2D Plot')
# Out:
# Text(0.5, 1.0, '2D Plot')

# %% [markdown]
# ## 3D Plot

# %%
fig = plt.figure(1, figsize=(10, 10))
ax = Axes3D(fig, elev=-150, azim=110)
y = range(0, len(X_reduced))
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k')
ax.set_title("PCA 3D Plot")
# Out:
# Text(0.5, 0.92, 'PCA 3D Plot')

# %% [markdown]
# ## See the documents/users with highest MSE

# %%
inverse_transform_data = pca.inverse_transform(X_reduced)
MSE_score = ((data_scaled-inverse_transform_data)**2).sum(axis=1)

# %%
MSE_max_scores = list(MSE_score.nlargest(10).index)

# %%
docs_with_highest_mse_df = users_to_documents_df.iloc[MSE_max_scores]
docs_with_highest_mse_df
# Out:
#                           0        1         2         3          4     \
# desmondyuen1     siliconvalley     love      uber  everyone       else
# _algocapital           britain  capital       key    market       uber
# dougwalker43         sadiqkhan   tfltph   thelcdc   theltda   guardian
# douglasviplimo            goit      get    simply      best  chauffeur
# trackitn                  meet    jerry  suleiman       ceo   longtino
# miami_nice2               uber      bus      stop      hour        ago
# talkmarkets               uber   report    record      cash       burn
# lwdaytrading              uber    didnt      live      hype     create
# globaltravelmgt            car   rental      rate    remain     stable
# gregorybrent           reality      set  investor     begin   question
#
#                       5          6                 7           8     \
# desmondyuen1     jeffbezos   alphabet          softbank     goldman
# _algocapital          home    million              user      driver
# dougwalker43          uber       make               pay      proper
# douglasviplimo         nyc  newjersey              area        know
# trackitn               nig        ltd            highly      esteem
# miami_nice2           hate        car           anymore       thank
# talkmarkets        billion       loss             first     quarter
# lwdaytrading           ipo       many  tradersinvestors  industrial
# globaltravelmgt     around      world              next       month
# gregorybrent       whether       uber              lyft        ever
#
#                                  9     ...  1626  1627  1628  1629  1630  \
# desmondyuen1     pictwittercomyetcmmc  ...  None  None  None  None  None
# _algocapital                 presence  ...  None  None  None  None  None
# dougwalker43                     wage  ...  None  None  None  None  None
# douglasviplimo                   area  ...  None  None  None  None  None
# trackitn                     customer  ...  None  None  None  None  None
# miami_nice2                      uber  ...  None  None  None  None  None
# talkmarkets                    public  ...  None  None  None  None  None
# lwdaytrading                   trader  ...  None  None  None  None  None
# globaltravelmgt                   use  ...  None  None  None  None  None
# gregorybrent               profitable  ...  None  None  None  None  None
#
#                  1631  1632  1633  1634  1635
# desmondyuen1     None  None  None  None  None
# _algocapital     None  None  None  None  None
# dougwalker43     None  None  None  None  None
# douglasviplimo   None  None  None  None  None
# trackitn         None  None  None  None  None
# miami_nice2      None  None  None  None  None
# talkmarkets      None  None  None  None  None
# lwdaytrading     None  None  None  None  None
# globaltravelmgt  None  None  None  None  None
# gregorybrent     None  None  None  None  None
#
# [10 rows x 1636 columns]

# %% [markdown]
# ### See the length of the documents/users with highest MSE

# %%
usernames_with_highest_mse = list(docs_with_highest_mse_df.index)
lengths_of_docs_with_highest_mse_df = pd.DataFrame.from_dict({u:len(users_to_documents[u]) for u in usernames_with_highest_mse}, orient='index', columns=['count']).sort_values(by='count', ascending=False)
lengths_of_docs_with_highest_mse_df
# Out:
#                  count
# _algocapital       219
# lwdaytrading       209
# douglasviplimo     202
# miami_nice2        201
# talkmarkets        189
# gregorybrent       187
# desmondyuen1       171
# dougwalker43       171
# globaltravelmgt    159
# trackitn           154

# %% [markdown]
# ## See the documents/users with the lowest MSE

# %%
MSE_low_scores = list(MSE_score.nsmallest(10).index)

# %%
docs_with_lowest_mse_df = users_to_documents_df.iloc[MSE_low_scores]
docs_with_lowest_mse_df
# Out:
#                        0               1               2            3     \
# bottyy                woman             sue            uber       driver
# somanymatts1            eat         cheerio           think      uberipo
# rlrottman              uber           begin            make        rider
# rustybroo               may         uberipo             day    meanwhile
# _drivers_united      effect  uberlyftstrike            keep  reverberate
# tommyparry1           thing            help          brings        toxic
# goodwatercap     historical         pattern  transformation      suggest
# robinskaplan      financial           daily            dose       reifmd
# crideshare           anyone             use          mystro        heard
# spkenny67              less         equally      ridiculous          fly
#
#                       4          5         6              7     \
# bottyy              groped     breast       via  georgeosborne
# somanymatts1     jimcramer      dkhos     ubers           path
# rlrottman         feedback     rating  actually           mean
# rustybroo             back       uber   support            bot
# _drivers_united        let       keep  pressure   driversunite
# tommyparry1        company       good   thelcdc      taxileaks
# goodwatercap         first  advantage     enter         market
# robinskaplan           top      story      uber          share
# crideshare            lyft      block       try         awhile
# spkenny67              car      still      year            ill
#
#                                8                        9     ...  1626  1627  \
# bottyy                         must                     miss  ...  None  None
# somanymatts1          profitability                 involves  ...  None  None
# rlrottman                 something                  foresee  ...  None  None
# rustybroo                     never                    sleep  ...  None  None
# _drivers_united  fairfaresfairwages  pictwittercomlegvdmqjsy  ...  None  None
# tommyparry1               mikeisaac                  gizmodo  ...  None  None
# goodwatercap                  early                  iterate  ...  None  None
# robinskaplan                   dive                    rocky  ...  None  None
# crideshare                    cause                  problem  ...  None  None
# spkenny67                 surprised                     uber  ...  None  None
#
#                  1628  1629  1630  1631  1632  1633  1634  1635
# bottyy           None  None  None  None  None  None  None  None
# somanymatts1     None  None  None  None  None  None  None  None
# rlrottman        None  None  None  None  None  None  None  None
# rustybroo        None  None  None  None  None  None  None  None
# _drivers_united  None  None  None  None  None  None  None  None
# tommyparry1      None  None  None  None  None  None  None  None
# goodwatercap     None  None  None  None  None  None  None  None
# robinskaplan     None  None  None  None  None  None  None  None
# crideshare       None  None  None  None  None  None  None  None
# spkenny67        None  None  None  None  None  None  None  None
#
# [10 rows x 1636 columns]

# %% [markdown]
# ### See the length of the documents/users with lowest MSE

# %%
usernames_with_lowest_mse = list(docs_with_lowest_mse_df.index)
lengths_of_docs_with_lowest_mse_df = pd.DataFrame.from_dict({u:len(users_to_documents[u]) for u in usernames_with_lowest_mse}, orient='index', columns=['count']).sort_values(by='count', ascending=False)
lengths_of_docs_with_lowest_mse_df
# Out:
#                  count
# rlrottman          489
# bottyy             412
# _drivers_united    333
# goodwatercap       324
# spkenny67          292
# tommyparry1        291
# crideshare         245
# somanymatts1       213
# robinskaplan       199
# rustybroo          155

# %%
# number of components
n_pcs= pca.components_.shape[0]

# get the index of the most important feature on EACH component
# LIST COMPREHENSION HERE
most_important_feature_indexes_per_pc = {}

initial_feature_names = data_scaled.columns

dfs = []

for pc in range(n_pcs):
    components_enumerated = list(enumerate(pca.components_[pc]))
    components_sorted = sorted(components_enumerated, key=lambda x:np.abs(x[1]), reverse=True)
    features_imps = {initial_feature_names[i]:imp for (i, imp) in components_sorted}
    features_imps_df = pd.DataFrame.from_dict(features_imps, orient='index', columns = ['importance'] )[:20]
    dfs.append(features_imps_df)
    
i = 1
for df in dfs:
    print('PCA %d' % i)
    print(df)
    print('')
    i += 1
# Out:
# PCA 1
#            importance
# uberipo      0.916097
# car         -0.137439
# ride        -0.118195
# rideshare   -0.103546
# taxi        -0.101678
# app         -0.100693
# drive       -0.093676
# share        0.092947
# passenger   -0.088419
# people      -0.078567
# investor     0.078406
# make        -0.073096
# strike      -0.069197
# city        -0.064365
# work        -0.062886
# take        -0.061009
# rider       -0.059169
# market       0.051610
# stock        0.050928
# dont        -0.050375
#
# PCA 2
#            importance
# stock        0.438476
# billion      0.318333
# uberipo     -0.276489
# market       0.248356
# price        0.246128
# share        0.245084
# investor     0.231340
# public       0.231255
# drive       -0.157129
# rideshare   -0.154034
# ride        -0.146240
# passenger   -0.146208
# invest       0.141340
# ubers        0.135675
# dont        -0.134349
# loss         0.133751
# know        -0.120072
# car         -0.116433
# work        -0.110003
# year         0.109711
#
# PCA 3
#            importance
# rideshare    0.792733
# taxi        -0.387359
# know        -0.206127
# stock        0.179816
# like        -0.156292
# business    -0.137028
# ride         0.115174
# car         -0.104155
# service     -0.103755
# rider        0.090764
# investor     0.081046
# passenger    0.054861
# billion     -0.053105
# say         -0.049940
# take        -0.048515
# even        -0.047639
# need        -0.046951
# first       -0.046924
# good        -0.043377
# app         -0.042812
#
# PCA 4
#            importance
# taxi         0.450350
# rideshare    0.284031
# drive       -0.217540
# city         0.215300
# time        -0.201723
# make        -0.194687
# app          0.190923
# business     0.175224
# good        -0.171980
# day         -0.157253
# still       -0.154747
# car          0.147932
# like        -0.145772
# money       -0.142347
# price       -0.128405
# bad         -0.127785
# one         -0.126811
# billion      0.124340
# stock       -0.123303
# dont        -0.123223
#
# PCA 5
#          importance
# stock      0.514931
# know       0.280026
# ride      -0.237253
# billion   -0.220931
# public    -0.217226
# share     -0.213839
# strike    -0.212513
# rider     -0.201890
# taxi       0.198602
# ubers     -0.195113
# price     -0.187333
# app       -0.169585
# invest     0.157506
# city      -0.132502
# make      -0.131439
# first     -0.131425
# day       -0.123669
# could     -0.098007
# would      0.088242
# take      -0.084947
#
# PCA 6
#            importance
# car          0.423378
# stock        0.338459
# rideshare   -0.304451
# taxi        -0.278723
# app          0.231004
# invest       0.229195
# pay          0.205942
# know        -0.194695
# price       -0.193459
# billion      0.173804
# share       -0.167699
# market      -0.166681
# passenger    0.157313
# dont        -0.145407
# ride         0.144083
# rider        0.140060
# public      -0.134238
# ubers       -0.116582
# strike       0.102389
# also        -0.100370
#
# PCA 7
#           importance
# ride        0.474849
# city       -0.379159
# rider       0.283708
# car        -0.278790
# app         0.276327
# taxi        0.213247
# business   -0.212457
# strike     -0.194161
# drive      -0.189504
# know        0.168677
# work       -0.148078
# dont       -0.137396
# public     -0.116509
# billion    -0.114526
# big        -0.106961
# start       0.097901
# new        -0.089871
# need       -0.089656
# price       0.087699
# pay         0.087671
#
# PCA 8
#            importance
# car          0.474228
# strike      -0.392244
# drive        0.345400
# work        -0.302875
# pay         -0.266292
# passenger    0.200979
# new         -0.152783
# would        0.134934
# market       0.133915
# use         -0.127157
# city        -0.127042
# could        0.117689
# share        0.117062
# rideshare    0.115187
# year         0.113405
# billion      0.103083
# stock       -0.098092
# today       -0.097625
# say          0.094857
# may         -0.090708
#
# PCA 9
#            importance
# passenger   -0.454136
# business     0.412688
# strike      -0.328030
# taxi        -0.283272
# ride         0.254459
# use          0.214132
# drive       -0.170460
# ubers       -0.154309
# dont         0.143352
# share       -0.139515
# big          0.138374
# market       0.122263
# still        0.113069
# way         -0.112487
# say         -0.112381
# car          0.106340
# app          0.103181
# city        -0.086899
# take         0.086487
# people       0.083536
#
# PCA 10
#           importance
# use         0.330341
# business   -0.328168
# right      -0.250331
# billion     0.240426
# strike     -0.233182
# today       0.219225
# public     -0.217801
# market     -0.217764
# many       -0.188762
# pay        -0.186405
# rider      -0.182754
# ride       -0.171856
# could      -0.168665
# say        -0.162473
# price       0.160965
# year       -0.154311
# share       0.135497
# know       -0.135350
# investor   -0.132824
# still       0.131901
#
# PCA 11
#           importance
# market      0.338721
# billion    -0.300544
# investor   -0.297735
# use         0.280579
# know       -0.263643
# rider      -0.258798
# drive       0.244088
# need       -0.214093
# city        0.206940
# like       -0.190932
# dont       -0.144690
# year        0.134105
# public      0.127218
# today       0.126343
# pay        -0.123801
# would      -0.123079
# make       -0.116072
# share      -0.108880
# stock       0.106800
# loss       -0.105592
#
# PCA 12
#            importance
# passenger    0.407454
# city        -0.309430
# drive       -0.300130
# right        0.269079
# ubers       -0.236156
# billion      0.230088
# say          0.189407
# rider       -0.185121
# business     0.178405
# dont        -0.172729
# stock       -0.170991
# investor    -0.164655
# ride        -0.149802
# still        0.144595
# know        -0.131361
# price       -0.128070
# app          0.127977
# like         0.106386
# car         -0.105339
# come         0.102913
#
# PCA 13
#            importance
# drive       -0.375964
# ubers        0.308088
# billion     -0.287241
# invest      -0.277685
# passenger    0.249850
# car          0.233434
# stock        0.184481
# take         0.179672
# one          0.176446
# year        -0.175664
# never       -0.169695
# new          0.157443
# use          0.154967
# still        0.153583
# price        0.143195
# today       -0.137001
# bad          0.134970
# business     0.134362
# strike      -0.121815
# work        -0.103735
#
# PCA 14
#            importance
# dont        -0.296033
# billion     -0.287019
# app          0.286378
# pay         -0.271244
# market      -0.263603
# investor     0.263097
# city         0.223882
# also        -0.194834
# strike      -0.173940
# right        0.170424
# use         -0.170180
# taxi        -0.165604
# share        0.153869
# make        -0.151646
# say          0.141576
# look         0.132798
# rider       -0.126894
# passenger   -0.126674
# never       -0.123761
# new          0.122271
#
# PCA 15
#            importance
# city        -0.346693
# car          0.287855
# ride        -0.241218
# make        -0.226249
# passenger   -0.220241
# even        -0.214646
# billion     -0.208382
# well         0.204938
# investor    -0.203339
# today        0.198319
# price        0.197417
# work         0.193173
# market       0.181508
# app          0.181125
# call        -0.157060
# say          0.149842
# day          0.144820
# big          0.140151
# rider        0.137345
# use         -0.132552
#
# PCA 16
#            importance
# pay          0.376844
# ubers       -0.326859
# invest      -0.313152
# share        0.262028
# market       0.225501
# car          0.219436
# still        0.215638
# good         0.213416
# city         0.209521
# business    -0.197844
# dont        -0.163838
# well         0.157943
# use         -0.139478
# rider       -0.139204
# passenger   -0.136234
# drive       -0.136153
# like         0.133302
# year         0.126582
# today       -0.118267
# loss        -0.109529
#
# PCA 17
#           importance
# big         0.337354
# taxi        0.243946
# investor    0.242661
# say         0.231000
# know       -0.214351
# business   -0.213390
# billion    -0.198634
# rider       0.197103
# ubers      -0.192898
# make        0.185529
# invest      0.176344
# right       0.173083
# pay        -0.171771
# money       0.165148
# use         0.163780
# way         0.157086
# year        0.155225
# never       0.151854
# good       -0.150561
# public      0.149383
#
# PCA 18
#           importance
# know        0.440331
# business   -0.298559
# taxi       -0.288673
# today      -0.236973
# good       -0.236669
# new         0.194682
# price      -0.192910
# ubers       0.186766
# first       0.184060
# right      -0.173177
# need        0.165524
# rider      -0.158134
# say         0.157364
# app         0.147147
# work       -0.137387
# service     0.135773
# use         0.135531
# come        0.129576
# want       -0.129198
# big         0.125656
#
# PCA 19
#            importance
# big          0.370248
# may         -0.327796
# price       -0.244672
# investor     0.238313
# know        -0.224124
# make        -0.216388
# first        0.211517
# day          0.209127
# right       -0.178811
# passenger    0.177371
# pay          0.177240
# drive        0.165577
# public      -0.164908
# ubers        0.162213
# car         -0.161597
# loss         0.144547
# taxi         0.135146
# share       -0.127200
# take         0.119495
# good         0.113255
#
# PCA 20
#           importance
# good        0.382501
# rider       0.321361
# people     -0.307013
# need       -0.270843
# city        0.242836
# take       -0.205071
# say         0.191262
# like        0.176718
# share      -0.173800
# ride       -0.165568
# want        0.164317
# drive      -0.156349
# taxi       -0.148669
# price      -0.141239
# year        0.135039
# investor   -0.125109
# start       0.123659
# call       -0.121769
# big        -0.121753
# bad         0.119763
#
# PCA 21
#            importance
# need         0.396259
# public      -0.317379
# use         -0.273879
# many        -0.251063
# strike       0.219172
# people      -0.207085
# well        -0.205218
# know        -0.200872
# passenger   -0.195770
# work        -0.186796
# market       0.185970
# like         0.172022
# time         0.170360
# still        0.144736
# investor    -0.137165
# could        0.131798
# call         0.129628
# ubers        0.115531
# new          0.115330
# may          0.112019
#
# PCA 22
#            importance
# use          0.357258
# pay          0.294037
# take        -0.265309
# drive        0.231510
# big         -0.227460
# passenger   -0.206767
# ride        -0.206564
# may         -0.201071
# right        0.200726
# work        -0.180757
# say          0.167672
# investor     0.166808
# invest      -0.166749
# know        -0.160159
# business     0.159133
# also         0.155809
# app          0.154388
# public      -0.144762
# share        0.143981
# good        -0.143113
#
# PCA 23
#           importance
# right       0.336799
# say         0.313002
# investor   -0.296099
# invest      0.270045
# people      0.263459
# strike     -0.252863
# pay         0.232382
# use        -0.191485
# first       0.186297
# work       -0.175041
# city        0.172832
# want        0.153675
# loss       -0.151248
# ubers       0.148099
# dont        0.138397
# billion     0.136573
# price       0.130244
# many       -0.125163
# business   -0.123360
# also        0.119516
#
# PCA 24
#           importance
# dont        0.349660
# ubers      -0.257963
# market      0.251618
# time        0.240564
# investor    0.211399
# work       -0.199968
# may        -0.196634
# app         0.193689
# drive      -0.189676
# use        -0.179141
# city        0.178558
# like       -0.178454
# want        0.160180
# would      -0.153520
# billion    -0.149226
# bad        -0.144202
# even       -0.138394
# year       -0.132608
# make        0.126499
# today       0.126474
#
# PCA 25
#          importance
# could      0.480358
# invest     0.325275
# many       0.242519
# right     -0.224682
# service   -0.216177
# drive     -0.211027
# well       0.204079
# new       -0.200569
# work      -0.197381
# think      0.179719
# take       0.173237
# look       0.151133
# stock     -0.134120
# much      -0.128555
# year       0.126911
# time      -0.126117
# public    -0.122130
# pay        0.121909
# billion   -0.115055
# like      -0.103407
#
# PCA 26
#         importance
# many     -0.279893
# rider     0.266320
# still    -0.264739
# invest   -0.264309
# take      0.254815
# bad      -0.252074
# today     0.236654
# strike   -0.231179
# way       0.222983
# ubers    -0.216528
# big       0.205468
# ride     -0.170706
# price    -0.157544
# call      0.137542
# car      -0.137494
# much     -0.123850
# could     0.121821
# pay       0.117618
# new       0.117568
# loss     -0.114595
#
# PCA 27
#            importance
# may         -0.270493
# year        -0.258210
# invest      -0.222772
# right        0.217048
# pay         -0.216617
# service     -0.206036
# money       -0.185909
# many         0.184260
# good        -0.181742
# share       -0.180329
# passenger   -0.176344
# billion      0.173255
# public      -0.171916
# today       -0.166229
# week        -0.166220
# see          0.164794
# say         -0.161081
# rider        0.150412
# come         0.147130
# app         -0.146267
#
# PCA 28
#          importance
# need      -0.325602
# app       -0.291897
# way        0.262886
# may       -0.247371
# loss      -0.242832
# well      -0.197119
# many      -0.193688
# stock     -0.178669
# new       -0.175145
# taxi      -0.174864
# invest     0.170028
# like       0.168519
# one        0.162504
# see       -0.149672
# take      -0.141631
# also      -0.141406
# billion   -0.138357
# ubers      0.133784
# let       -0.131289
# even      -0.130580
#
# PCA 29
#           importance
# rider      -0.356026
# could       0.257670
# dont        0.255654
# invest     -0.253811
# right       0.216861
# ride        0.209976
# investor    0.197351
# loss       -0.196740
# new        -0.182249
# market     -0.181523
# car         0.178346
# city       -0.177830
# also        0.177148
# many       -0.157961
# price      -0.154730
# still      -0.154307
# make       -0.149553
# good        0.141462
# strike      0.132526
# last       -0.127437
#
# PCA 30
#          importance
# way       -0.328491
# service   -0.283109
# may        0.238067
# work      -0.231757
# app       -0.229669
# well      -0.214250
# year      -0.199790
# take       0.191619
# could     -0.186114
# say        0.185364
# stock     -0.185039
# dont      -0.181346
# let        0.173901
# also      -0.171602
# last      -0.168816
# see       -0.162388
# day       -0.159822
# one       -0.150709
# call      -0.137759
# money      0.130511
#
# PCA 31
#            importance
# today        0.356252
# dont        -0.340094
# investor     0.311533
# share       -0.281384
# make         0.271334
# money        0.247938
# ubers        0.214011
# strike      -0.204790
# market       0.189383
# big         -0.172732
# also         0.169290
# way         -0.156599
# work         0.137934
# one          0.137867
# drive       -0.127609
# right        0.124692
# week        -0.116063
# take         0.110077
# rideshare    0.103505
# taxi         0.097694
#
# PCA 32
#         importance
# work     -0.422685
# one       0.280381
# bad       0.273412
# also      0.214554
# big       0.214092
# loss      0.209492
# look     -0.208773
# start     0.195780
# may       0.192035
# dont     -0.182741
# people    0.166502
# could    -0.163480
# ubers    -0.158757
# still    -0.150625
# invest   -0.149513
# share    -0.139053
# market   -0.137116
# want     -0.131443
# public   -0.127568
# well      0.125893
#
# PCA 33
#           importance
# many        0.327295
# money      -0.316306
# look       -0.262241
# never       0.227480
# say        -0.221287
# loss       -0.219836
# share       0.217487
# business   -0.211547
# even        0.180890
# well       -0.179236
# right       0.176065
# drive      -0.156168
# big         0.152949
# take       -0.144787
# know       -0.140948
# ubers       0.138320
# ride       -0.136239
# public     -0.133562
# pay        -0.130324
# way        -0.125780
#
# PCA 34
#           importance
# could       0.428098
# app         0.287346
# loss        0.261320
# make        0.217860
# people      0.191530
# year       -0.187518
# start      -0.176613
# well       -0.168040
# never       0.167753
# see        -0.167297
# many       -0.163269
# investor   -0.158776
# public      0.149437
# price       0.144417
# come       -0.144129
# use         0.136925
# rider      -0.136133
# share      -0.135779
# last       -0.128975
# look       -0.128826
#
# PCA 35
#           importance
# make        0.284541
# think       0.263923
# need       -0.247224
# business    0.246665
# invest     -0.232974
# market     -0.232485
# today       0.211867
# many        0.206259
# stock       0.199330
# let         0.189578
# new         0.177349
# year        0.176459
# also       -0.172980
# look        0.166974
# right      -0.159927
# investor   -0.155432
# work       -0.151675
# money       0.142533
# see        -0.133121
# use        -0.131030
#
# PCA 36
#          importance
# today     -0.360432
# even      -0.279755
# big       -0.267093
# loss      -0.257573
# like      -0.255782
# day        0.251574
# still      0.245152
# service   -0.239037
# people     0.222000
# ride      -0.184832
# want      -0.172141
# first      0.150348
# know      -0.145129
# market    -0.129886
# rider      0.121261
# way        0.118877
# see       -0.117118
# may        0.107652
# strike    -0.105693
# come       0.105493
#
# PCA 37
#         importance
# never     0.420497
# still     0.259742
# loss      0.225963
# people   -0.222388
# like     -0.210972
# week     -0.208852
# today     0.193813
# would     0.192623
# market   -0.182574
# drive    -0.170047
# year      0.168798
# know      0.167999
# time      0.167270
# app      -0.161017
# bad      -0.145627
# start    -0.145366
# dont     -0.140778
# many     -0.139315
# city      0.138783
# big       0.135914
#
# PCA 38
#            importance
# public       0.289057
# could       -0.268157
# big         -0.265045
# loss         0.262294
# money       -0.236564
# new         -0.224079
# give        -0.211390
# take         0.183456
# passenger   -0.177346
# much        -0.175145
# good         0.165502
# let          0.158136
# business    -0.157972
# want         0.155336
# need         0.153541
# never       -0.149850
# see          0.149516
# people       0.145996
# price       -0.130677
# make         0.130318
#
# PCA 39
#         importance
# say      -0.316153
# day      -0.307488
# still     0.279754
# start     0.240887
# way       0.201434
# one      -0.199070
# last     -0.198658
# also      0.191330
# use      -0.182310
# big       0.181371
# new      -0.177960
# public    0.174107
# people   -0.168245
# app       0.165117
# well     -0.155870
# let       0.154741
# money     0.154195
# first     0.146625
# price     0.146160
# come      0.139364
#
# PCA 40
#           importance
# still      -0.326925
# also       -0.308331
# service    -0.306606
# way         0.305037
# need        0.228514
# loss       -0.225866
# want        0.212197
# use         0.206076
# see         0.199369
# price       0.159529
# think      -0.150229
# many        0.145544
# ubers       0.145390
# give        0.144412
# market      0.132274
# rider      -0.131787
# could      -0.127749
# business    0.124882
# money       0.121714
# app         0.111997
#
# PCA 41
#           importance
# share      -0.288917
# take       -0.273916
# time        0.271950
# public      0.261292
# year       -0.218142
# call        0.206247
# still       0.194975
# like        0.192588
# also       -0.190016
# week        0.185976
# make       -0.179736
# one         0.166537
# day        -0.159984
# billion     0.159224
# last        0.143705
# investor    0.143054
# start      -0.134806
# see         0.133445
# would      -0.130861
# money      -0.130643
#
# PCA 42
#           importance
# money       0.339693
# make       -0.274428
# loss        0.267602
# day        -0.227076
# want       -0.220009
# use        -0.206135
# year        0.205479
# business   -0.187278
# well       -0.183911
# first      -0.171289
# time       -0.168194
# invest     -0.167457
# may        -0.147866
# dont        0.147616
# service    -0.139894
# look       -0.137180
# strike     -0.136472
# way         0.134275
# good       -0.133108
# share      -0.132691
#
# PCA 43
#          importance
# never     -0.366629
# take      -0.362536
# bad       -0.282752
# need       0.267753
# time       0.211777
# start      0.208738
# think      0.175715
# day       -0.171011
# service    0.170071
# still     -0.169314
# app       -0.162529
# dont      -0.153619
# billion   -0.147613
# week      -0.137881
# would      0.136643
# well       0.127738
# one       -0.125874
# want       0.123252
# drive     -0.121452
# see       -0.120018
#
# PCA 44
#          importance
# week      -0.357972
# new       -0.301419
# people     0.269725
# want      -0.227286
# service    0.221743
# take       0.204567
# like       0.185795
# even      -0.176290
# last      -0.169376
# stock      0.165587
# loss      -0.163102
# city       0.156710
# today      0.154278
# work      -0.153955
# app        0.153483
# would      0.152138
# strike     0.140374
# car       -0.135686
# right     -0.126096
# first     -0.122677
#
# PCA 45
#          importance
# look      -0.347486
# pay       -0.286227
# may       -0.281235
# many      -0.280308
# way       -0.262669
# well       0.248366
# service   -0.241381
# come       0.224087
# call       0.197501
# much      -0.166570
# want       0.156807
# day       -0.149053
# loss      -0.147101
# money      0.144807
# say        0.130593
# even       0.128099
# strike     0.122628
# time      -0.118854
# week       0.118669
# work       0.114117
#
# PCA 46
#           importance
# also        0.333376
# start      -0.320248
# let        -0.282346
# want        0.257473
# right      -0.244320
# one        -0.223987
# share      -0.222189
# call       -0.209118
# time       -0.202247
# price       0.173917
# even       -0.157745
# know       -0.153398
# first       0.133437
# give       -0.132910
# invest     -0.132270
# investor    0.123598
# ride        0.122831
# loss       -0.116891
# new         0.111161
# week        0.110808
#
# PCA 47
#          importance
# want      -0.351367
# good       0.269692
# today     -0.269482
# make       0.256816
# also       0.219313
# service   -0.219298
# call       0.199577
# day       -0.181822
# week      -0.178800
# people    -0.167051
# still     -0.165099
# way       -0.164938
# come      -0.162382
# public     0.162006
# look       0.153495
# would     -0.151925
# bad       -0.150663
# see        0.147668
# start     -0.134625
# know      -0.130681
#
# PCA 48
#          importance
# much       0.362103
# even       0.287541
# also      -0.263840
# look       0.240309
# one       -0.235789
# let       -0.224067
# would     -0.199148
# start      0.197011
# week       0.182494
# first      0.171574
# ride      -0.162125
# billion   -0.158617
# think     -0.149194
# many      -0.142501
# year       0.141825
# want      -0.141685
# way       -0.140412
# public    -0.140239
# see        0.129509
# new       -0.129437
#
# PCA 49
#           importance
# time       -0.432705
# would       0.393450
# year       -0.234465
# may         0.228943
# dont        0.215826
# come        0.213488
# make        0.183775
# new        -0.164641
# take       -0.162895
# loss        0.159460
# pay         0.133202
# investor    0.132794
# say         0.127893
# need       -0.126911
# one        -0.126166
# rider      -0.125654
# money      -0.122478
# call        0.118899
# give        0.112323
# strike     -0.110217
#
# PCA 50
#          importance
# week       0.302595
# day        0.268260
# let        0.260740
# work      -0.259060
# call       0.257343
# time      -0.224412
# one       -0.214696
# would      0.197020
# app       -0.194287
# much       0.189925
# may       -0.174778
# like       0.161598
# way       -0.145403
# say       -0.141189
# bad       -0.140737
# right      0.140155
# last      -0.138796
# billion   -0.126395
# public     0.124786
# rider      0.123714
#
# PCA 51
#          importance
# would     -0.327955
# one       -0.282787
# like       0.277546
# money     -0.242490
# see       -0.242099
# service   -0.224266
# day        0.215239
# start      0.198684
# price     -0.189211
# today      0.189187
# public     0.184742
# first     -0.173284
# last      -0.165201
# let       -0.164895
# strike    -0.142759
# say        0.136918
# many       0.127163
# good      -0.120611
# look      -0.119157
# time       0.117916
#
# PCA 52
#        importance
# new      0.406109
# need    -0.352657
# come     0.327529
# never    0.245279
# say     -0.227831
# like     0.192153
# bad     -0.182869
# time     0.157351
# big     -0.155236
# week    -0.152082
# take     0.149459
# may      0.147679
# use     -0.145089
# would    0.141888
# well     0.141697
# make    -0.140424
# city    -0.133931
# see      0.132273
# still   -0.131977
# first   -0.121815
#
# PCA 53
#            importance
# look        -0.303507
# many         0.300983
# say          0.280926
# think       -0.245577
# come         0.229589
# even        -0.222328
# call         0.210929
# take         0.208051
# time         0.192434
# like        -0.166836
# good         0.157624
# first        0.156206
# well        -0.151074
# public      -0.140124
# work         0.137634
# service      0.134947
# may         -0.134303
# passenger   -0.134134
# bad         -0.132576
# day         -0.129076
#
# PCA 54
#          importance
# even       0.343996
# service   -0.308436
# never     -0.285516
# let       -0.225975
# would      0.225634
# price      0.219544
# make      -0.214009
# like       0.213534
# well      -0.208499
# ubers     -0.191379
# time       0.174028
# year       0.172752
# first      0.169544
# want      -0.154646
# see       -0.135421
# week      -0.132590
# come      -0.131538
# could     -0.130847
# also       0.120199
# much      -0.116703
#
# PCA 55
#         importance
# bad       0.358154
# new       0.292172
# public    0.253173
# look      0.246704
# would     0.241586
# may      -0.236408
# today     0.216809
# let      -0.214689
# like     -0.212038
# much     -0.210328
# day      -0.205087
# also     -0.195757
# dont      0.166553
# give     -0.162407
# think    -0.148171
# want     -0.147967
# many      0.137170
# ubers    -0.133602
# work     -0.129513
# year     -0.119542
#
# PCA 56
#            importance
# much         0.345136
# one          0.270250
# call        -0.263568
# market      -0.249074
# think       -0.225099
# investor    -0.218311
# even         0.200403
# know        -0.189114
# people      -0.175364
# public       0.166648
# time        -0.161512
# good        -0.158261
# want         0.157715
# come         0.149107
# week        -0.148027
# start       -0.145235
# ubers       -0.141194
# use         -0.140784
# need         0.137445
# passenger   -0.136227
#
# PCA 57
#        importance
# give     0.509357
# think   -0.296598
# one     -0.272914
# week     0.251819
# last     0.240893
# start   -0.209449
# would    0.198627
# time     0.191250
# call    -0.166439
# come    -0.146539
# price   -0.145189
# pay     -0.134557
# say     -0.131845
# much    -0.130092
# good    -0.128374
# big      0.125568
# take     0.123307
# never   -0.119443
# ride    -0.102160
# work    -0.101617
#
# PCA 58
#          importance
# much      -0.384859
# price      0.268878
# also      -0.251321
# service    0.219957
# make       0.217096
# new       -0.214800
# share     -0.211700
# well       0.189168
# take       0.172843
# way       -0.169117
# year       0.166699
# see       -0.161031
# think     -0.159628
# good      -0.158566
# people    -0.155905
# dont       0.148882
# strike    -0.147002
# look      -0.142303
# start     -0.141869
# let        0.137450
#
# PCA 59
#          importance
# see        0.459549
# well      -0.354024
# good      -0.234408
# much      -0.214377
# year      -0.213181
# right     -0.203582
# still     -0.196812
# think      0.167961
# say        0.153380
# day        0.149737
# first      0.143167
# big       -0.139321
# ubers     -0.133402
# never      0.129946
# one       -0.126500
# app       -0.125376
# service    0.123845
# look      -0.123466
# use       -0.122560
# work       0.116806
#
# PCA 60
#         importance
# week      0.429535
# call     -0.321970
# people   -0.236671
# one       0.235417
# never     0.229694
# think     0.217861
# see      -0.196462
# year     -0.181681
# would     0.172615
# want     -0.166086
# could    -0.160884
# bad      -0.160692
# last     -0.158388
# start     0.154412
# well      0.152541
# even      0.144148
# drive    -0.143869
# still    -0.141375
# may      -0.119316
# ride      0.113558
#
# PCA 61
#          importance
# start      0.385642
# come      -0.318295
# give      -0.314306
# good      -0.297128
# would      0.257759
# last       0.234510
# even      -0.231749
# much       0.188248
# people    -0.180593
# like       0.154155
# never     -0.153512
# bad        0.135337
# want       0.128188
# money     -0.113368
# know      -0.112767
# service   -0.107224
# right     -0.104099
# invest    -0.100370
# still      0.098737
# many      -0.096823
#
# PCA 62
#        importance
# let     -0.408231
# call     0.284643
# look     0.276515
# money    0.251784
# even    -0.243762
# week     0.240607
# new     -0.212842
# come     0.211769
# way     -0.203449
# want     0.166283
# could   -0.163202
# good    -0.159489
# say     -0.141586
# many     0.137096
# still   -0.136086
# like     0.122992
# see     -0.116274
# make    -0.113889
# app      0.113791
# take     0.113726
#
# PCA 63
#         importance
# give     -0.446165
# think    -0.350000
# year     -0.239268
# well      0.225776
# first     0.219011
# let       0.218893
# people    0.213597
# may       0.178081
# share     0.174596
# money     0.173593
# bad      -0.170529
# way       0.156642
# price    -0.148865
# time      0.148447
# week      0.146410
# public   -0.137328
# start    -0.130791
# ride      0.116010
# pay      -0.113584
# city      0.112954
#
# PCA 64
#         importance
# think     0.331269
# look     -0.316241
# well      0.236739
# first     0.235132
# work     -0.218415
# start    -0.213748
# price    -0.205922
# let      -0.202928
# come     -0.202726
# big      -0.199265
# people   -0.193986
# also     -0.189078
# money     0.188214
# way       0.167005
# like      0.157097
# take      0.148015
# much      0.145895
# city     -0.141582
# may       0.132799
# never    -0.129494
#
# PCA 65
#            importance
# call         0.397292
# see         -0.382631
# want         0.245127
# give         0.220786
# way          0.216106
# come        -0.192776
# first        0.186133
# let          0.173210
# never        0.169869
# look         0.169353
# even         0.161952
# big         -0.156723
# last         0.150011
# passenger   -0.149510
# right       -0.147959
# think        0.143790
# week        -0.140236
# day         -0.138947
# year        -0.136086
# ride        -0.129294
#
# PCA 66
#          importance
# first      0.505973
# even      -0.323125
# like       0.242234
# bad        0.230137
# day       -0.225531
# money     -0.211053
# come       0.204242
# way       -0.189402
# last       0.162556
# see       -0.161464
# call      -0.149181
# want      -0.144866
# think      0.139602
# let        0.136560
# service   -0.136172
# share      0.123127
# never      0.119877
# give       0.114037
# ubers     -0.113183
# use        0.100263
#
# PCA 67
#        importance
# bad      0.371726
# start   -0.326801
# much     0.281639
# come     0.249932
# let      0.229924
# still   -0.221187
# last    -0.211003
# time     0.199542
# give    -0.185652
# also     0.169254
# never   -0.164578
# think    0.156495
# want    -0.150302
# way      0.148734
# right   -0.145878
# one     -0.144454
# like    -0.140381
# would    0.140177
# year     0.140129
# first   -0.139755
#
# PCA 68
#        importance
# last    -0.623787
# one      0.264999
# year     0.233974
# come    -0.223841
# look     0.178753
# think   -0.174323
# good    -0.162855
# give     0.160167
# want     0.158437
# call     0.147772
# see      0.145203
# day     -0.136744
# price   -0.134185
# like     0.128510
# take    -0.126936
# loss     0.119834
# much    -0.110305
# even    -0.105654
# week     0.104291
# let      0.101678

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import Normalizer

# %%
normalizer = Normalizer(copy=False)
X_reduced_normalized = normalizer.fit_transform(X_reduced)
km = KMeans(n_clusters=4)
distances = km.fit_transform(X_reduced_normalized)

# %% [markdown]
# ## Plotting the clusters

# %%
y_kmeans = km.labels_
plt.figure(figsize=(15, 15))
plt.scatter(X_reduced_normalized[:, 0], X_reduced_normalized[:, 1], c=y_kmeans, s=50, cmap='viridis')
centers = km.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
original_space_centroids = pca.inverse_transform(km.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(4):
    print("Cluster %d:" % i, end='')
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind], end='')
        print()
# Out:
# Cluster 0: taxi
#  ride
#  get
#  driver
#  car
#  app
#  make
#  drive
#  like
#  today
# Cluster 1: ipo
#  stock
#  billion
#  price
#  market
#  share
#  public
#  company
#  investor
#  ubers
# Cluster 2: uberipo
#  driver
#  ipo
#  share
#  investor
#  get
#  market
#  like
#  price
#  well
# Cluster 3: driver
#  get
#  pay
#  strike
#  ride
#  car
#  make
#  take
#  drive
#  people

# %% [markdown]
# ## Get the users per cluster

# %%
cluster_df = pd.DataFrame()
cluster_df['user'] = users_to_documents_df.index
cluster_df['cluster'] = km.labels_
cluster_df['distance_to_0'] = distances[:, 0]
cluster_df['distance_to_1'] = distances[:, 1]
cluster_df['distance_to_2'] = distances[:, 2]
cluster_df['distance_to_3'] = distances[:, 3]

# %%
# Cluster 0
users_cluster0 = cluster_df.loc[cluster_df['cluster'] == 0]
users_cluster0
# Cluster 1
users_cluster1 = cluster_df.loc[cluster_df['cluster'] == 1]
# Cluster 2
users_cluster2 = cluster_df.loc[cluster_df['cluster'] == 2]
# Cluster 3
users_cluster3 = cluster_df.loc[cluster_df['cluster'] == 3]

# %% [markdown]
# ## Get the tweets per cluster

# %%
tweets_cluster0 = [t for t in tweets if t['username'] in list(users_cluster0['user'])]    
tweets_cluster1 = [t for t in tweets if t['username'] in list(users_cluster1['user'])]
tweets_cluster2 = [t for t in tweets if t['username'] in list(users_cluster2['user'])]
tweets_cluster3 = [t for t in tweets if t['username'] in list(users_cluster3['user'])]
texts_cluster0 = [t['tweet'] for t in tweets_cluster0]
texts_cluster1 = [t['tweet'] for t in tweets_cluster1]
texts_cluster2 = [t['tweet'] for t in tweets_cluster2]
texts_cluster3 = [t['tweet'] for t in tweets_cluster3]
print(texts_cluster2)
